# %% [markdown]
# ### Import configuration and data.

# %%
# %load_ext autoreload
# %autoreload 2

from trainer import *

trainer = load_trainer(path='../output/Upwind_avg_static/base_Upwind_avg_static/trainer.pkl')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Gaussian process-based Bayes hyperparameter optimization (Optional)

# %% [markdown]
# ### Training

# %%
trainer.plot_loss()

# %% [markdown]
# ### Plotting predictions and comparing with baseline models.

# %%
trainer.plot_truth_pred(log_trans=True, upper_lim=5)
# Out:
# Train Loss: 0.1499, R2: 0.3046
# Validation Loss: 0.0512, R2: 0.6407
# Test Loss: 0.2354, R2: 0.1776
# Train Loss: 0.1499, R2: 0.3046
# Validation Loss: 0.0512, R2: 0.6407
# Test Loss: 0.2354, R2: 0.1776

# %% [markdown]
# ### Permutation feature importance

# %%
trainer.plot_feature_importance()

# %% [markdown]
# ### Partial dependence

# %%
trainer.plot_partial_dependence(log_trans=True, lower_lim=1, upper_lim=4)
# Out:
# Calculate PDP:  Thickness
# Calculate PDP:  Width
# Calculate PDP:  Area
# Calculate PDP:  Length(gauge)
# Calculate PDP:  0-deg layers
# Calculate PDP:  45-deg layers
# Calculate PDP:  90-deg layers
# Calculate PDP:  Other-deg layers
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: divide by zero encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/hdd/ML-fracture/src/utils.py:349: UserWarning: Attempting to set identical left == right == -0.2948839068412781 results in singular transformations; automatically expanding.
#   ax2.set_xlim([np.min(x_values_list[idx]), np.max(x_values_list[idx])])
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: divide by zero encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/hdd/ML-fracture/src/utils.py:349: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax2.set_xlim([np.min(x_values_list[idx]), np.max(x_values_list[idx])])
# Calculate PDP:  Thickness
# Calculate PDP:  Width
# Calculate PDP:  Area
# Calculate PDP:  Length(gauge)
# Calculate PDP:  0-deg layers
# Calculate PDP:  45-deg layers
# Calculate PDP:  90-deg layers
# Calculate PDP:  Other-deg layers
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: divide by zero encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/hdd/ML-fracture/src/utils.py:349: UserWarning: Attempting to set identical left == right == -0.2948839068412781 results in singular transformations; automatically expanding.
#   ax2.set_xlim([np.min(x_values_list[idx]), np.max(x_values_list[idx])])
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: divide by zero encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/hdd/ML-fracture/src/utils.py:349: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax2.set_xlim([np.min(x_values_list[idx]), np.max(x_values_list[idx])])

# %%
trainer.plot_partial_err(0.1)
# Out:
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: divide by zero encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %% [markdown]
# ## Baseline models

# %%
trainer.get_leaderboard(test_data_only=False)
# Out:
# Pytorch-Tabular metrics
# AutoGluon metrics
# This work metrics
# TabNet metrics
#             Program                      Model  Train RMSE  Train MSE  \
# 0         AutoGluon    ExtraTreesMSE_BAG_L1/T0    0.163411   0.026703
# 1         AutoGluon   NeuralNetMXNet_BAG_L1/T0    0.205436   0.042204
# 2         AutoGluon       LightGBMLarge_BAG_L1    0.215915   0.046619
# 3         AutoGluon         CatBoost_BAG_L1/T0    0.231657   0.053665
# 4         AutoGluon        WeightedEnsemble_L2    0.218629   0.047799
# 5   Pytorch-Tabular     CategoryEmbeddingModel    0.459998   0.211598
# 6         This work                         --    0.387151   0.149886
# 7         AutoGluon  RandomForestMSE_BAG_L1/T0    0.160134   0.025643
# 8         AutoGluon   KNeighborsDist_BAG_L1/T0    0.000000   0.000000
# 9         AutoGluon         LightGBM_BAG_L1/T0    0.464249   0.215527
# 10        AutoGluon       LightGBMXT_BAG_L1/T0    0.464249   0.215527
# 11        AutoGluon   KNeighborsUnif_BAG_L1/T0    0.397839   0.158276
# 12        AutoGluon          XGBoost_BAG_L1/T0    0.178075   0.031711
# 13        AutoGluon  NeuralNetFastAI_BAG_L1/T0    0.468624   0.219608
# 14  Pytorch-Tabular               AutoIntModel    1.037204   1.075792
# 15  Pytorch-Tabular                TabNetModel    0.796953   0.635134
# 16  Pytorch-Tabular        TabTransformerModel    0.891330   0.794468
# 17           TabNet                     TabNet    5.187863  26.913923
#
#     Train MAE  Train MAPE    Train R2  Test RMSE   Test MSE  Test MAE  \
# 0    0.128164    0.053710    0.876103   0.342777   0.117496  0.257973
# 1    0.178129    0.072469    0.804183   0.379082   0.143703  0.275495
# 2    0.172779    0.070867    0.783696   0.452853   0.205076  0.380969
# 3    0.205378    0.087652    0.751005   0.468699   0.219679  0.382370
# 4    0.183818    0.076428    0.778225   0.470761   0.221616  0.399924
# 5    0.322767    0.142818    0.018231   0.484378   0.234622  0.353533
# 6    0.273428    0.118823    0.304562   0.485211   0.235429  0.351501
# 7    0.127097    0.053597    0.881023   0.494206   0.244239  0.384315
# 8    0.000000    0.000000    1.000000   0.525974   0.276649  0.380330
# 9    0.432444    0.181845    0.000000   0.556621   0.309827  0.479068
# 10   0.432444    0.181845    0.000000   0.556621   0.309827  0.479068
# 11   0.328944    0.137662    0.265633   0.556667   0.309879  0.492575
# 12   0.150084    0.055717    0.852869   0.564740   0.318931  0.448479
# 13   0.431263    0.182925   -0.018934   0.568974   0.323731  0.489296
# 14   0.650734    0.277331   -3.991438   0.711262   0.505893  0.540984
# 15   0.686574    0.248389   -1.946882   0.824427   0.679680  0.758913
# 16   0.739355    0.304444   -2.686160   0.972744   0.946231  0.760784
# 17   2.681882    1.039006 -123.874744   6.559073  43.021446  4.097963
#
#     Test MAPE     Test R2  Validation RMSE  Validation MSE  Validation MAE  \
# 0    0.120122    0.589550         0.370267        0.137097        0.312949
# 1    0.125110    0.497999         0.361607        0.130760        0.302030
# 2    0.165585    0.283604         0.293225        0.085981        0.261262
# 3    0.182598    0.232593         0.333953        0.111524        0.296940
# 4    0.174821    0.225827         0.280770        0.078832        0.225336
# 5    0.143269    0.180392         0.220797        0.048751        0.177025
# 6    0.169985    0.177572         0.226296        0.051210        0.209971
# 7    0.163347    0.146795         0.291918        0.085216        0.227812
# 8    0.172097    0.033579         0.349901        0.122430        0.309867
# 9    0.232841   -0.082324         0.435600        0.189747        0.410379
# 10   0.232841   -0.082324         0.435600        0.189747        0.410379
# 11   0.220460   -0.082503         0.351020        0.123215        0.340176
# 12   0.194608   -0.114126         0.328251        0.107749        0.277622
# 13   0.238335   -0.130896         0.415330        0.172499        0.385441
# 14   0.236558   -0.767244         0.160850        0.025873        0.123641
# 15   0.323797   -1.374337         0.996131        0.992278        0.994487
# 16   0.299021   -2.305483         0.497465        0.247472        0.408404
# 17   1.508394 -149.287457         0.691740        0.478504        0.561938
#
#     Validation MAPE  Validation R2
# 0          0.111494       0.038066
# 1          0.106803       0.082535
# 2          0.094628       0.396721
# 3          0.109456       0.217497
# 4          0.082386       0.446883
# 5          0.062023       0.657941
# 6          0.073132       0.640689
# 7          0.080274       0.402086
# 8          0.105323       0.140976
# 9          0.157774      -0.331346
# 10         0.157774      -0.331346
# 11         0.123488       0.135469
# 12         0.098944       0.243990
# 13         0.149628      -0.210325
# 14         0.042109       0.818467
# 15         0.357923      -5.962243
# 16         0.155879      -0.736366
# 17         0.196805      -2.357392
# Pytorch-Tabular metrics
# AutoGluon metrics
# This work metrics
# TabNet metrics
#             Program                      Model  Train RMSE  Train MSE  \
# 0         AutoGluon    ExtraTreesMSE_BAG_L1/T0    0.163411   0.026703
# 1         AutoGluon   NeuralNetMXNet_BAG_L1/T0    0.205436   0.042204
# 2         AutoGluon       LightGBMLarge_BAG_L1    0.215915   0.046619
# 3         AutoGluon         CatBoost_BAG_L1/T0    0.231657   0.053665
# 4         AutoGluon        WeightedEnsemble_L2    0.218629   0.047799
# 5   Pytorch-Tabular     CategoryEmbeddingModel    0.459998   0.211598
# 6         This work                         --    0.387151   0.149886
# 7         AutoGluon  RandomForestMSE_BAG_L1/T0    0.160134   0.025643
# 8         AutoGluon   KNeighborsDist_BAG_L1/T0    0.000000   0.000000
# 9         AutoGluon         LightGBM_BAG_L1/T0    0.464249   0.215527
# 10        AutoGluon       LightGBMXT_BAG_L1/T0    0.464249   0.215527
# 11        AutoGluon   KNeighborsUnif_BAG_L1/T0    0.397839   0.158276
# 12        AutoGluon          XGBoost_BAG_L1/T0    0.178075   0.031711
# 13        AutoGluon  NeuralNetFastAI_BAG_L1/T0    0.468624   0.219608
# 14  Pytorch-Tabular               AutoIntModel    1.037204   1.075792
# 15  Pytorch-Tabular                TabNetModel    0.796953   0.635134
# 16  Pytorch-Tabular        TabTransformerModel    0.891330   0.794468
# 17           TabNet                     TabNet    5.187863  26.913923
#
#     Train MAE  Train MAPE    Train R2  Test RMSE   Test MSE  Test MAE  \
# 0    0.128164    0.053710    0.876103   0.342777   0.117496  0.257973
# 1    0.178129    0.072469    0.804183   0.379082   0.143703  0.275495
# 2    0.172779    0.070867    0.783696   0.452853   0.205076  0.380969
# 3    0.205378    0.087652    0.751005   0.468699   0.219679  0.382370
# 4    0.183818    0.076428    0.778225   0.470761   0.221616  0.399924
# 5    0.322767    0.142818    0.018231   0.484378   0.234622  0.353533
# 6    0.273428    0.118823    0.304562   0.485211   0.235429  0.351501
# 7    0.127097    0.053597    0.881023   0.494206   0.244239  0.384315
# 8    0.000000    0.000000    1.000000   0.525974   0.276649  0.380330
# 9    0.432444    0.181845    0.000000   0.556621   0.309827  0.479068
# 10   0.432444    0.181845    0.000000   0.556621   0.309827  0.479068
# 11   0.328944    0.137662    0.265633   0.556667   0.309879  0.492575
# 12   0.150084    0.055717    0.852869   0.564740   0.318931  0.448479
# 13   0.431263    0.182925   -0.018934   0.568974   0.323731  0.489296
# 14   0.650734    0.277331   -3.991438   0.711262   0.505893  0.540984
# 15   0.686574    0.248389   -1.946882   0.824427   0.679680  0.758913
# 16   0.739355    0.304444   -2.686160   0.972744   0.946231  0.760784
# 17   2.681882    1.039006 -123.874744   6.559073  43.021446  4.097963
#
#     Test MAPE     Test R2  Validation RMSE  Validation MSE  Validation MAE  \
# 0    0.120122    0.589550         0.370267        0.137097        0.312949
# 1    0.125110    0.497999         0.361607        0.130760        0.302030
# 2    0.165585    0.283604         0.293225        0.085981        0.261262
# 3    0.182598    0.232593         0.333953        0.111524        0.296940
# 4    0.174821    0.225827         0.280770        0.078832        0.225336
# 5    0.143269    0.180392         0.220797        0.048751        0.177025
# 6    0.169985    0.177572         0.226296        0.051210        0.209971
# 7    0.163347    0.146795         0.291918        0.085216        0.227812
# 8    0.172097    0.033579         0.349901        0.122430        0.309867
# 9    0.232841   -0.082324         0.435600        0.189747        0.410379
# 10   0.232841   -0.082324         0.435600        0.189747        0.410379
# 11   0.220460   -0.082503         0.351020        0.123215        0.340176
# 12   0.194608   -0.114126         0.328251        0.107749        0.277622
# 13   0.238335   -0.130896         0.415330        0.172499        0.385441
# 14   0.236558   -0.767244         0.160850        0.025873        0.123641
# 15   0.323797   -1.374337         0.996131        0.992278        0.994487
# 16   0.299021   -2.305483         0.497465        0.247472        0.408404
# 17   1.508394 -149.287457         0.691740        0.478504        0.561938
#
#     Validation MAPE  Validation R2
# 0          0.111494       0.038066
# 1          0.106803       0.082535
# 2          0.094628       0.396721
# 3          0.109456       0.217497
# 4          0.082386       0.446883
# 5          0.062023       0.657941
# 6          0.073132       0.640689
# 7          0.080274       0.402086
# 8          0.105323       0.140976
# 9          0.157774      -0.331346
# 10         0.157774      -0.331346
# 11         0.123488       0.135469
# 12         0.098944       0.243990
# 13         0.149628      -0.210325
# 14         0.042109       0.818467
# 15         0.357923      -5.962243
# 16         0.155879      -0.736366
# 17         0.196805      -2.357392

# %%
trainer.plot_truth_pred(program='pytorch_tabular', upper_lim=5)
# Out:
# Making baseline predictions...
# CategoryEmbeddingModel 1/4
# AutoIntModel 2/4
# TabNetModel 3/4
# TabTransformerModel 4/4
# Plotting...
# CategoryEmbeddingModel 1/4
# Train Loss: 0.2116, R2: 0.0182
# Validation Loss: 0.0488, R2: 0.6579
# Test Loss: 0.2346, R2: 0.1804
# AutoIntModel 2/4
# Train Loss: 1.0758, R2: -3.9914
# Validation Loss: 0.0259, R2: 0.8185
# Test Loss: 0.5059, R2: -0.7672
# TabNetModel 3/4
# Train Loss: 0.6351, R2: -1.9469
# Validation Loss: 0.9923, R2: -5.9622
# Test Loss: 0.6797, R2: -1.3743
# TabTransformerModel 4/4
# Train Loss: 0.7945, R2: -2.6862
# Validation Loss: 0.2475, R2: -0.7364
# Test Loss: 0.9462, R2: -2.3055
# Making baseline predictions...
# CategoryEmbeddingModel 1/4
# AutoIntModel 2/4
# TabNetModel 3/4
# TabTransformerModel 4/4
# Plotting...
# CategoryEmbeddingModel 1/4
# Train Loss: 0.2116, R2: 0.0182
# Validation Loss: 0.0488, R2: 0.6579
# Test Loss: 0.2346, R2: 0.1804
# AutoIntModel 2/4
# Train Loss: 1.0758, R2: -3.9914
# Validation Loss: 0.0259, R2: 0.8185
# Test Loss: 0.5059, R2: -0.7672
# TabNetModel 3/4
# Train Loss: 0.6351, R2: -1.9469
# Validation Loss: 0.9923, R2: -5.9622
# Test Loss: 0.6797, R2: -1.3743
# TabTransformerModel 4/4
# Train Loss: 0.7945, R2: -2.6862
# Validation Loss: 0.2475, R2: -0.7364
# Test Loss: 0.9462, R2: -2.3055

# %%
trainer.plot_truth_pred(program='autogluon', upper_lim=5)
# Out:
# Making baseline predictions...
# ExtraTreesMSE_BAG_L1/T0 1/12
# NeuralNetMXNet_BAG_L1/T0 2/12
# LightGBMLarge_BAG_L1 3/12
# CatBoost_BAG_L1/T0 4/12
# WeightedEnsemble_L2 5/12
# RandomForestMSE_BAG_L1/T0 6/12
# KNeighborsDist_BAG_L1/T0 7/12
# LightGBM_BAG_L1/T0 8/12
# LightGBMXT_BAG_L1/T0 9/12
# KNeighborsUnif_BAG_L1/T0 10/12
# XGBoost_BAG_L1/T0 11/12
# NeuralNetFastAI_BAG_L1/T0 12/12
# Plotting...
# ExtraTreesMSE_BAG_L1/T0 1/12
# Train Loss: 0.0267, R2: 0.8761
# Validation Loss: 0.1371, R2: 0.0381
# Test Loss: 0.1175, R2: 0.5896
# NeuralNetMXNet_BAG_L1/T0 2/12
# Train Loss: 0.0422, R2: 0.8042
# Validation Loss: 0.1308, R2: 0.0825
# Test Loss: 0.1437, R2: 0.4980
# LightGBMLarge_BAG_L1 3/12
# Train Loss: 0.0466, R2: 0.7837
# Validation Loss: 0.0860, R2: 0.3967
# Test Loss: 0.2051, R2: 0.2836
# CatBoost_BAG_L1/T0 4/12
# Train Loss: 0.0537, R2: 0.7510
# Validation Loss: 0.1115, R2: 0.2175
# Test Loss: 0.2197, R2: 0.2326
# WeightedEnsemble_L2 5/12
# Train Loss: 0.0478, R2: 0.7782
# Validation Loss: 0.0788, R2: 0.4469
# Test Loss: 0.2216, R2: 0.2258
# RandomForestMSE_BAG_L1/T0 6/12
# Train Loss: 0.0256, R2: 0.8810
# Validation Loss: 0.0852, R2: 0.4021
# Test Loss: 0.2442, R2: 0.1468
# KNeighborsDist_BAG_L1/T0 7/12
# Train Loss: 0.0000, R2: 1.0000
# Validation Loss: 0.1224, R2: 0.1410
# Test Loss: 0.2766, R2: 0.0336
# LightGBM_BAG_L1/T0 8/12
# Train Loss: 0.2155, R2: 0.0000
# Validation Loss: 0.1897, R2: -0.3313
# Test Loss: 0.3098, R2: -0.0823
# LightGBMXT_BAG_L1/T0 9/12
# Train Loss: 0.2155, R2: 0.0000
# Validation Loss: 0.1897, R2: -0.3313
# Test Loss: 0.3098, R2: -0.0823
# KNeighborsUnif_BAG_L1/T0 10/12
# Train Loss: 0.1583, R2: 0.2656
# Validation Loss: 0.1232, R2: 0.1355
# Test Loss: 0.3099, R2: -0.0825
# XGBoost_BAG_L1/T0 11/12
# Train Loss: 0.0317, R2: 0.8529
# Validation Loss: 0.1077, R2: 0.2440
# Test Loss: 0.3189, R2: -0.1141
# NeuralNetFastAI_BAG_L1/T0 12/12
# Train Loss: 0.2196, R2: -0.0189
# Validation Loss: 0.1725, R2: -0.2103
# Test Loss: 0.3237, R2: -0.1309
# Making baseline predictions...
# ExtraTreesMSE_BAG_L1/T0 1/12
# NeuralNetMXNet_BAG_L1/T0 2/12
# LightGBMLarge_BAG_L1 3/12
# CatBoost_BAG_L1/T0 4/12
# WeightedEnsemble_L2 5/12
# RandomForestMSE_BAG_L1/T0 6/12
# KNeighborsDist_BAG_L1/T0 7/12
# LightGBM_BAG_L1/T0 8/12
# LightGBMXT_BAG_L1/T0 9/12
# KNeighborsUnif_BAG_L1/T0 10/12
# XGBoost_BAG_L1/T0 11/12
# NeuralNetFastAI_BAG_L1/T0 12/12
# Plotting...
# ExtraTreesMSE_BAG_L1/T0 1/12
# Train Loss: 0.0267, R2: 0.8761
# Validation Loss: 0.1371, R2: 0.0381
# Test Loss: 0.1175, R2: 0.5896
# NeuralNetMXNet_BAG_L1/T0 2/12
# Train Loss: 0.0422, R2: 0.8042
# Validation Loss: 0.1308, R2: 0.0825
# Test Loss: 0.1437, R2: 0.4980
# LightGBMLarge_BAG_L1 3/12
# Train Loss: 0.0466, R2: 0.7837
# Validation Loss: 0.0860, R2: 0.3967
# Test Loss: 0.2051, R2: 0.2836
# CatBoost_BAG_L1/T0 4/12
# Train Loss: 0.0537, R2: 0.7510
# Validation Loss: 0.1115, R2: 0.2175
# Test Loss: 0.2197, R2: 0.2326
# WeightedEnsemble_L2 5/12
# Train Loss: 0.0478, R2: 0.7782
# Validation Loss: 0.0788, R2: 0.4469
# Test Loss: 0.2216, R2: 0.2258
# RandomForestMSE_BAG_L1/T0 6/12
# Train Loss: 0.0256, R2: 0.8810
# Validation Loss: 0.0852, R2: 0.4021
# Test Loss: 0.2442, R2: 0.1468
# KNeighborsDist_BAG_L1/T0 7/12
# Train Loss: 0.0000, R2: 1.0000
# Validation Loss: 0.1224, R2: 0.1410
# Test Loss: 0.2766, R2: 0.0336
# LightGBM_BAG_L1/T0 8/12
# Train Loss: 0.2155, R2: 0.0000
# Validation Loss: 0.1897, R2: -0.3313
# Test Loss: 0.3098, R2: -0.0823
# LightGBMXT_BAG_L1/T0 9/12
# Train Loss: 0.2155, R2: 0.0000
# Validation Loss: 0.1897, R2: -0.3313
# Test Loss: 0.3098, R2: -0.0823
# KNeighborsUnif_BAG_L1/T0 10/12
# Train Loss: 0.1583, R2: 0.2656
# Validation Loss: 0.1232, R2: 0.1355
# Test Loss: 0.3099, R2: -0.0825
# XGBoost_BAG_L1/T0 11/12
# Train Loss: 0.0317, R2: 0.8529
# Validation Loss: 0.1077, R2: 0.2440
# Test Loss: 0.3189, R2: -0.1141
# NeuralNetFastAI_BAG_L1/T0 12/12
# Train Loss: 0.2196, R2: -0.0189
# Validation Loss: 0.1725, R2: -0.2103
# Test Loss: 0.3237, R2: -0.1309
