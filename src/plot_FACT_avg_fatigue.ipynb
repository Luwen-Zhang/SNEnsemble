# %% [markdown]
# ### Import configuration and data.

# %%
# %load_ext autoreload
# %autoreload 2

from trainer import *

trainer = load_trainer(path='../output/FACT_avg_fatigue/base_FACT_avg_fatigue/trainer.pkl')

# %% [markdown]
# ### Gaussian process-based Bayes hyperparameter optimization (Optional)

# %% [markdown]
# ### Training

# %%
trainer.plot_loss()

# %% [markdown]
# ### Plotting predictions and comparing with baseline models.

# %%
trainer.plot_truth_pred(log_trans=True, upper_lim=9)
# Out:
# Train Loss: 0.4311, R2: 0.8487
# Validation Loss: 0.7219, R2: 0.7273
# Test Loss: 0.5670, R2: 0.7628

# %% [markdown]
# ### Permutation feature importance

# %%
trainer.plot_feature_importance()

# %% [markdown]
# ### Partial dependence

# %%
trainer.plot_partial_dependence(log_trans=True, lower_lim=2, upper_lim=7)
# Out:
# Calculate PDP:  Percentage of Fibre in 0-deg Direction
# Calculate PDP:  Percentage of Fibre in 45-deg Direction
# Calculate PDP:  Percentage of Fibre in 90-deg Direction
# Calculate PDP:  Percentage of Fibre in Other Direction
# Calculate PDP:  Fibre Volumn Fraction
# Calculate PDP:  Thickness
# Calculate PDP:  Maximum Width
# Calculate PDP:  Area
# Calculate PDP:  Length
# Calculate PDP:  Maximum Strain
# Calculate PDP:  Maximum Stress
# Calculate PDP:  Frequency
# Calculate PDP:  Static Elastic Modulus
# Calculate PDP:  0-deg layers
# Calculate PDP:  45-deg layers
# Calculate PDP:  90-deg layers
# Calculate PDP:  Other-deg layers

# %%
trainer.plot_partial_err(0.5)

# %% [markdown]
# ## Baseline models

# %%
trainer.get_leaderboard(test_data_only=False)
# Out:
# Pytorch-Tabular metrics
# AutoGluon metrics
# This work metrics
# TabNet metrics
#             Program                      Model  Train RMSE  Train MSE  \
# 0         AutoGluon   NeuralNetMXNet_BAG_L1/T0    0.654815   0.428783
# 1         AutoGluon        WeightedEnsemble_L2    0.570924   0.325954
# 2   Pytorch-Tabular        TabTransformerModel    0.516826   0.267109
# 3   Pytorch-Tabular               AutoIntModel    0.688454   0.473969
# 4   Pytorch-Tabular     CategoryEmbeddingModel    0.613958   0.376945
# 5         This work                         --    0.656612   0.431140
# 6         AutoGluon       LightGBMXT_BAG_L1/T0    0.584572   0.341725
# 7         AutoGluon         CatBoost_BAG_L1/T0    0.398561   0.158851
# 8         AutoGluon         LightGBM_BAG_L1/T0    0.563145   0.317132
# 9         AutoGluon    ExtraTreesMSE_BAG_L1/T0    0.332691   0.110683
# 10        AutoGluon       LightGBMLarge_BAG_L1    0.321341   0.103260
# 11        AutoGluon  NeuralNetFastAI_BAG_L1/T0    0.637282   0.406128
# 12        AutoGluon  RandomForestMSE_BAG_L1/T0    0.336075   0.112947
# 13        AutoGluon          XGBoost_BAG_L1/T0    0.253436   0.064230
# 14        AutoGluon   KNeighborsDist_BAG_L1/T0    0.000000   0.000000
# 15        AutoGluon   KNeighborsUnif_BAG_L1/T0    1.120721   1.256016
# 16  Pytorch-Tabular                TabNetModel    1.321442   1.746209
# 17           TabNet                     TabNet    1.344987   1.808989
#
#     Train MAE  Train MAPE  Train R2  Test RMSE  Test MSE  Test MAE  Test MAPE  \
# 0    0.459158    0.134806  0.849519   0.684476  0.468508  0.522879   0.122602
# 1    0.397649    0.113985  0.885607   0.706847  0.499633  0.536628   0.121454
# 2    0.313490    0.083785  0.906259   0.706851  0.499639  0.482798   0.108375
# 3    0.496258    0.138977  0.833662   0.740656  0.548572  0.554614   0.133913
# 4    0.421792    0.110738  0.867712   0.752111  0.565671  0.580418   0.131665
# 5    0.458059    0.130155  0.848692   0.753006  0.567018  0.533182   0.123132
# 6    0.423850    0.119524  0.880072   0.753860  0.568304  0.578827   0.133271
# 7    0.306697    0.086294  0.944251   0.773032  0.597579  0.583372   0.135223
# 8    0.401877    0.114273  0.888703   0.793538  0.629703  0.627388   0.146175
# 9    0.237519    0.067316  0.961156   0.798441  0.637508  0.612296   0.140337
# 10   0.233077    0.066845  0.963761   0.799882  0.639811  0.631133   0.148276
# 11   0.440774    0.120071  0.857470   0.803457  0.645543  0.559296   0.126761
# 12   0.243760    0.069123  0.960362   0.812358  0.659926  0.642584   0.146763
# 13   0.191015    0.047829  0.977459   0.842769  0.710259  0.613301   0.133898
# 14   0.000000    0.000000  1.000000   1.065382  1.135039  0.810789   0.189746
# 15   0.845739    0.235610  0.559203   1.142425  1.305134  0.910178   0.216124
# 16   1.094249    0.325877  0.387171   1.290494  1.665375  1.086381   0.270026
# 17   1.066692    0.275430  0.365139   1.516041  2.298380  1.261422   0.277437
#
#      Test R2  Validation RMSE  Validation MSE  Validation MAE  \
# 0   0.803977         0.881391        0.776850        0.681107
# 1   0.790955         0.849640        0.721888        0.647370
# 2   0.790952         0.769285        0.591799        0.566444
# 3   0.770479         0.769968        0.592851        0.602553
# 4   0.763325         0.785736        0.617381        0.579662
# 5   0.762761         0.849673        0.721944        0.637196
# 6   0.762223         0.904247        0.817663        0.684958
# 7   0.749975         0.902354        0.814242        0.693544
# 8   0.736534         0.891374        0.794547        0.689206
# 9   0.733268         0.936924        0.877827        0.721826
# 10  0.732305         0.903134        0.815651        0.700428
# 11  0.729907         0.890252        0.792549        0.648005
# 12  0.723889         0.926201        0.857848        0.730467
# 13  0.702829         0.953066        0.908335        0.713480
# 14  0.525103         1.171556        1.372542        0.890458
# 15  0.453935         1.260186        1.588068        1.031319
# 16  0.303211         1.276574        1.629641        1.010102
# 17  0.038364         1.391962        1.937557        1.177894
#
#     Validation MAPE  Validation R2
# 0          0.188597       0.706566
# 1          0.176635       0.727326
# 2          0.154076       0.776464
# 3          0.158761       0.776067
# 4          0.157771       0.766801
# 5          0.171545       0.727305
# 6          0.185740       0.691150
# 7          0.189013       0.692442
# 8          0.190378       0.699881
# 9          0.197161       0.668424
# 10         0.190155       0.691910
# 11         0.164862       0.700636
# 12         0.196411       0.675971
# 13         0.182662       0.656901
# 14         0.250950       0.481559
# 15         0.285352       0.400150
# 16         0.277468       0.384447
# 17         0.283057       0.268140

# %%
trainer.plot_truth_pred(program='pytorch_tabular', upper_lim=9)
# Out:
# Making baseline predictions...
# TabTransformerModel 1/4
# AutoIntModel 2/4
# CategoryEmbeddingModel 3/4
# TabNetModel 4/4
# Plotting...
# TabTransformerModel 1/4
# Train Loss: 0.2671, R2: 0.9063
# Validation Loss: 0.5918, R2: 0.7765
# Test Loss: 0.4996, R2: 0.7910
# AutoIntModel 2/4
# Train Loss: 0.4740, R2: 0.8337
# Validation Loss: 0.5929, R2: 0.7761
# Test Loss: 0.5486, R2: 0.7705
# CategoryEmbeddingModel 3/4
# Train Loss: 0.3769, R2: 0.8677
# Validation Loss: 0.6174, R2: 0.7668
# Test Loss: 0.5657, R2: 0.7633
# TabNetModel 4/4
# Train Loss: 1.7462, R2: 0.3872
# Validation Loss: 1.6296, R2: 0.3844
# Test Loss: 1.6654, R2: 0.3032

# %%
trainer.plot_truth_pred(program='autogluon', upper_lim=9)
# Out:
# Making baseline predictions...
# NeuralNetMXNet_BAG_L1/T0 1/12
# WeightedEnsemble_L2 2/12
# LightGBMXT_BAG_L1/T0 3/12
# CatBoost_BAG_L1/T0 4/12
# LightGBM_BAG_L1/T0 5/12
# ExtraTreesMSE_BAG_L1/T0 6/12
# LightGBMLarge_BAG_L1 7/12
# NeuralNetFastAI_BAG_L1/T0 8/12
# RandomForestMSE_BAG_L1/T0 9/12
# XGBoost_BAG_L1/T0 10/12
# KNeighborsDist_BAG_L1/T0 11/12
# KNeighborsUnif_BAG_L1/T0 12/12
# Plotting...
# NeuralNetMXNet_BAG_L1/T0 1/12
# Train Loss: 0.4288, R2: 0.8495
# Validation Loss: 0.7768, R2: 0.7066
# Test Loss: 0.4685, R2: 0.8040
# WeightedEnsemble_L2 2/12
# Train Loss: 0.3260, R2: 0.8856
# Validation Loss: 0.7219, R2: 0.7273
# Test Loss: 0.4996, R2: 0.7910
# LightGBMXT_BAG_L1/T0 3/12
# Train Loss: 0.3417, R2: 0.8801
# Validation Loss: 0.8177, R2: 0.6911
# Test Loss: 0.5683, R2: 0.7622
# CatBoost_BAG_L1/T0 4/12
# Train Loss: 0.1589, R2: 0.9443
# Validation Loss: 0.8142, R2: 0.6924
# Test Loss: 0.5976, R2: 0.7500
# LightGBM_BAG_L1/T0 5/12
# Train Loss: 0.3171, R2: 0.8887
# Validation Loss: 0.7945, R2: 0.6999
# Test Loss: 0.6297, R2: 0.7365
# ExtraTreesMSE_BAG_L1/T0 6/12
# Train Loss: 0.1107, R2: 0.9612
# Validation Loss: 0.8778, R2: 0.6684
# Test Loss: 0.6375, R2: 0.7333
# LightGBMLarge_BAG_L1 7/12
# Train Loss: 0.1033, R2: 0.9638
# Validation Loss: 0.8157, R2: 0.6919
# Test Loss: 0.6398, R2: 0.7323
# NeuralNetFastAI_BAG_L1/T0 8/12
# Train Loss: 0.4061, R2: 0.8575
# Validation Loss: 0.7925, R2: 0.7006
# Test Loss: 0.6455, R2: 0.7299
# RandomForestMSE_BAG_L1/T0 9/12
# Train Loss: 0.1129, R2: 0.9604
# Validation Loss: 0.8578, R2: 0.6760
# Test Loss: 0.6599, R2: 0.7239
# XGBoost_BAG_L1/T0 10/12
# Train Loss: 0.0642, R2: 0.9775
# Validation Loss: 0.9083, R2: 0.6569
# Test Loss: 0.7103, R2: 0.7028
# KNeighborsDist_BAG_L1/T0 11/12
# Train Loss: 0.0000, R2: 1.0000
# Validation Loss: 1.3725, R2: 0.4816
# Test Loss: 1.1350, R2: 0.5251
# KNeighborsUnif_BAG_L1/T0 12/12
# Train Loss: 1.2560, R2: 0.5592
# Validation Loss: 1.5881, R2: 0.4001
# Test Loss: 1.3051, R2: 0.4539
