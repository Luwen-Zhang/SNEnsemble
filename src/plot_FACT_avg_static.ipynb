# %% [markdown]
# ### Import configuration and data.

# %%
# %load_ext autoreload
# %autoreload 2

from trainer import *

trainer = load_trainer(path='../output/FACT_avg_static/base_FACT_avg_static/trainer.pkl')

# %% [markdown]
# ### Gaussian process-based Bayes hyperparameter optimization (Optional)

# %% [markdown]
# ### Training

# %%
trainer.plot_loss()

# %% [markdown]
# ### Plotting predictions and comparing with baseline models.

# %%
trainer.plot_truth_pred(log_trans=True, upper_lim=5)
# Out:
# Train Loss: 0.0002, R2: 0.9961
# Validation Loss: 0.0002, R2: 0.9974
# Test Loss: 0.0003, R2: 0.9911

# %% [markdown]
# ### Permutation feature importance

# %%
trainer.plot_feature_importance()

# %% [markdown]
# ### Partial dependence

# %%
trainer.plot_partial_dependence(log_trans=True, lower_lim=1, upper_lim=4)
# Out:
# Calculate PDP:  Percentage of Fibre in 0-deg Direction
# Calculate PDP:  Percentage of Fibre in 45-deg Direction
# Calculate PDP:  Percentage of Fibre in 90-deg Direction
# Calculate PDP:  Percentage of Fibre in Other Direction
# Calculate PDP:  Fibre Volumn Fraction
# Calculate PDP:  Thickness
# Calculate PDP:  Maximum Width
# Calculate PDP:  Area
# Calculate PDP:  Length
# Calculate PDP:  Static Elastic Modulus
# Calculate PDP:  0-deg layers
# Calculate PDP:  45-deg layers
# Calculate PDP:  90-deg layers
# Calculate PDP:  Other-deg layers
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: divide by zero encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/hdd/ML-fracture/src/utils.py:349: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax2.set_xlim([np.min(x_values_list[idx]), np.max(x_values_list[idx])])

# %%
trainer.plot_partial_err(0.02)
# Out:
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: divide by zero encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %% [markdown]
# ## Baseline models

# %%
trainer.get_leaderboard(test_data_only=False)
# Out:
# Pytorch-Tabular metrics
# AutoGluon metrics
# This work metrics
# TabNet metrics
#             Program                      Model  Train RMSE  Train MSE  \
# 0         AutoGluon   KNeighborsDist_BAG_L1/T0    0.001349   0.000002
# 1         AutoGluon        WeightedEnsemble_L2    0.001349   0.000002
# 2         This work                         --    0.015270   0.000233
# 3         AutoGluon         CatBoost_BAG_L1/T0    0.010502   0.000110
# 4         AutoGluon       LightGBMLarge_BAG_L1    0.011886   0.000141
# 5         AutoGluon          XGBoost_BAG_L1/T0    0.012663   0.000160
# 6         AutoGluon         LightGBM_BAG_L1/T0    0.017074   0.000292
# 7         AutoGluon       LightGBMXT_BAG_L1/T0    0.015683   0.000246
# 8         AutoGluon  NeuralNetFastAI_BAG_L1/T0    0.018377   0.000338
# 9   Pytorch-Tabular               AutoIntModel    0.037264   0.001389
# 10  Pytorch-Tabular     CategoryEmbeddingModel    0.033455   0.001119
# 11        AutoGluon    ExtraTreesMSE_BAG_L1/T0    0.022386   0.000501
# 12        AutoGluon  RandomForestMSE_BAG_L1/T0    0.023768   0.000565
# 13  Pytorch-Tabular                TabNetModel    0.042347   0.001793
# 14        AutoGluon   KNeighborsUnif_BAG_L1/T0    0.045773   0.002095
# 15        AutoGluon   NeuralNetMXNet_BAG_L1/T0    0.171695   0.029479
# 16           TabNet                     TabNet    0.315693   0.099662
# 17  Pytorch-Tabular        TabTransformerModel    0.421953   0.178044
#
#     Train MAE  Train MAPE  Train R2  Test RMSE  Test MSE  Test MAE  Test MAPE  \
# 0    0.000207    0.000078  0.999969   0.009570  0.000092  0.002631   0.000964
# 1    0.000207    0.000078  0.999969   0.009570  0.000092  0.002631   0.000964
# 2    0.008295    0.003149  0.996089   0.015993  0.000256  0.009895   0.003668
# 3    0.001804    0.000773  0.998150   0.021452  0.000460  0.006912   0.002838
# 4    0.002773    0.001193  0.997630   0.023647  0.000559  0.008157   0.003369
# 5    0.005482    0.002165  0.997310   0.025345  0.000642  0.010396   0.004141
# 6    0.006950    0.003061  0.995110   0.025488  0.000650  0.010041   0.004112
# 7    0.006566    0.002822  0.995875   0.026941  0.000726  0.010918   0.004399
# 8    0.011141    0.004342  0.994335   0.027266  0.000743  0.014630   0.005755
# 9    0.029394    0.010955  0.976708   0.027960  0.000782  0.021882   0.008303
# 10   0.024581    0.009106  0.981226   0.028444  0.000809  0.021350   0.007842
# 11   0.003279    0.001513  0.991594   0.039535  0.001563  0.009761   0.004262
# 12   0.003932    0.001771  0.990524   0.041987  0.001763  0.010802   0.004697
# 13   0.032679    0.012920  0.969920   0.054400  0.002959  0.039304   0.015209
# 14   0.012014    0.004810  0.964857   0.076321  0.005825  0.024655   0.010310
# 15   0.136479    0.052082  0.505529   0.210292  0.044223  0.158297   0.059662
# 16   0.257132    0.098162 -0.671690   0.351001  0.123202  0.274923   0.101093
# 17   0.399776    0.150173 -1.986448   0.408009  0.166471  0.385175   0.142277
#
#      Test R2  Validation RMSE  Validation MSE  Validation MAE  \
# 0   0.996802         0.006252        0.000039        0.002717
# 1   0.996802         0.006252        0.000039        0.002717
# 2   0.991068         0.015083        0.000227        0.009001
# 3   0.983929         0.031678        0.001003        0.011120
# 4   0.980472         0.035188        0.001238        0.012964
# 5   0.977567         0.034871        0.001216        0.016899
# 6   0.977313         0.043046        0.001853        0.020324
# 7   0.974652         0.041129        0.001692        0.018753
# 8   0.974037         0.043006        0.001850        0.022234
# 9   0.972699         0.040392        0.001632        0.030558
# 10  0.971745         0.034207        0.001170        0.025574
# 11  0.945417         0.067200        0.004516        0.021535
# 12  0.938436         0.070823        0.005016        0.023192
# 13  0.896651         0.076909        0.005915        0.048863
# 14  0.796580         0.129680        0.016817        0.046706
# 15 -0.544371         0.189222        0.035805        0.149825
# 16 -3.302503         0.306463        0.093920        0.245872
# 17 -4.813589         0.420802        0.177074        0.390734
#
#     Validation MAPE  Validation R2
# 0          0.000998       0.999550
# 1          0.000998       0.999550
# 2          0.003400       0.997384
# 3          0.005063       0.988459
# 4          0.005897       0.985759
# 5          0.007290       0.986015
# 6          0.009126       0.978689
# 7          0.008407       0.980545
# 8          0.009543       0.978729
# 9          0.011739       0.981236
# 10         0.009597       0.986542
# 11         0.010107       0.948063
# 12         0.010837       0.942312
# 13         0.020579       0.931971
# 14         0.021118       0.806589
# 15         0.059056       0.588208
# 16         0.095064      -0.080168
# 17         0.146483      -1.036525

# %%
trainer.plot_truth_pred(program='pytorch_tabular', upper_lim=5)
# Out:
# Making baseline predictions...
# AutoIntModel 1/4
# CategoryEmbeddingModel 2/4
# TabNetModel 3/4
# TabTransformerModel 4/4
# Plotting...
# AutoIntModel 1/4
# Train Loss: 0.0014, R2: 0.9767
# Validation Loss: 0.0016, R2: 0.9812
# Test Loss: 0.0008, R2: 0.9727
# CategoryEmbeddingModel 2/4
# Train Loss: 0.0011, R2: 0.9812
# Validation Loss: 0.0012, R2: 0.9865
# Test Loss: 0.0008, R2: 0.9717
# TabNetModel 3/4
# Train Loss: 0.0018, R2: 0.9699
# Validation Loss: 0.0059, R2: 0.9320
# Test Loss: 0.0030, R2: 0.8967
# TabTransformerModel 4/4
# Train Loss: 0.1780, R2: -1.9864
# Validation Loss: 0.1771, R2: -1.0365
# Test Loss: 0.1665, R2: -4.8136

# %%
trainer.plot_truth_pred(program='autogluon', upper_lim=5)
# Out:
# Making baseline predictions...
# NeuralNetMXNet_BAG_L1/T0 1/12
# WeightedEnsemble_L2 2/12
# LightGBMXT_BAG_L1/T0 3/12
# CatBoost_BAG_L1/T0 4/12
# LightGBM_BAG_L1/T0 5/12
# ExtraTreesMSE_BAG_L1/T0 6/12
# LightGBMLarge_BAG_L1 7/12
# NeuralNetFastAI_BAG_L1/T0 8/12
# RandomForestMSE_BAG_L1/T0 9/12
# XGBoost_BAG_L1/T0 10/12
# KNeighborsDist_BAG_L1/T0 11/12
# KNeighborsUnif_BAG_L1/T0 12/12
# Plotting...
# NeuralNetMXNet_BAG_L1/T0 1/12
# Train Loss: 0.4288, R2: 0.8495
# Validation Loss: 0.7768, R2: 0.7066
# Test Loss: 0.4685, R2: 0.8040
# WeightedEnsemble_L2 2/12
# Train Loss: 0.3260, R2: 0.8856
# Validation Loss: 0.7219, R2: 0.7273
# Test Loss: 0.4996, R2: 0.7910
# LightGBMXT_BAG_L1/T0 3/12
# Train Loss: 0.3417, R2: 0.8801
# Validation Loss: 0.8177, R2: 0.6911
# Test Loss: 0.5683, R2: 0.7622
# CatBoost_BAG_L1/T0 4/12
# Train Loss: 0.1589, R2: 0.9443
# Validation Loss: 0.8142, R2: 0.6924
# Test Loss: 0.5976, R2: 0.7500
# LightGBM_BAG_L1/T0 5/12
# Train Loss: 0.3171, R2: 0.8887
# Validation Loss: 0.7945, R2: 0.6999
# Test Loss: 0.6297, R2: 0.7365
# ExtraTreesMSE_BAG_L1/T0 6/12
# Train Loss: 0.1107, R2: 0.9612
# Validation Loss: 0.8778, R2: 0.6684
# Test Loss: 0.6375, R2: 0.7333
# LightGBMLarge_BAG_L1 7/12
# Train Loss: 0.1033, R2: 0.9638
# Validation Loss: 0.8157, R2: 0.6919
# Test Loss: 0.6398, R2: 0.7323
# NeuralNetFastAI_BAG_L1/T0 8/12
# Train Loss: 0.4061, R2: 0.8575
# Validation Loss: 0.7925, R2: 0.7006
# Test Loss: 0.6455, R2: 0.7299
# RandomForestMSE_BAG_L1/T0 9/12
# Train Loss: 0.1129, R2: 0.9604
# Validation Loss: 0.8578, R2: 0.6760
# Test Loss: 0.6599, R2: 0.7239
# XGBoost_BAG_L1/T0 10/12
# Train Loss: 0.0642, R2: 0.9775
# Validation Loss: 0.9083, R2: 0.6569
# Test Loss: 0.7103, R2: 0.7028
# KNeighborsDist_BAG_L1/T0 11/12
# Train Loss: 0.0000, R2: 1.0000
# Validation Loss: 1.3725, R2: 0.4816
# Test Loss: 1.1350, R2: 0.5251
# KNeighborsUnif_BAG_L1/T0 12/12
# Train Loss: 1.2560, R2: 0.5592
# Validation Loss: 1.5881, R2: 0.4001
# Test Loss: 1.3051, R2: 0.4539
