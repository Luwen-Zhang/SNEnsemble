# %% [markdown]
# ### Import configuration and data.

# %%
# %load_ext autoreload
# %autoreload 2

from trainer import *

trainer = load_trainer(path='../output/Upwind_avg_fatigue/base_Upwind_avg_fatigue/trainer.pkl')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Gaussian process-based Bayes hyperparameter optimization (Optional)

# %% [markdown]
# ### Training

# %%
trainer.plot_loss()

# %% [markdown]
# ### Plotting predictions and comparing with baseline models.

# %%
trainer.plot_truth_pred(log_trans=True, upper_lim=9)
# Out:
# Train Loss: 0.5104, R2: 0.6621
# Validation Loss: 0.5986, R2: 0.5860
# Test Loss: 0.6452, R2: 0.5338

# %% [markdown]
# ### Permutation feature importance

# %%
trainer.plot_feature_importance()

# %% [markdown]
# ### Partial dependence

# %%
trainer.plot_partial_dependence(log_trans=True, lower_lim=2, upper_lim=7)
# Out:
# Calculate PDP:  Thickness
# Calculate PDP:  Width
# Calculate PDP:  Area
# Calculate PDP:  Length(gauge)
# Calculate PDP:  Frequency
# Calculate PDP:  Absolute Maximum Stress
# Calculate PDP:  Absolute Peak-to-peak Stress
# Calculate PDP:  0-deg layers
# Calculate PDP:  45-deg layers
# Calculate PDP:  90-deg layers
# Calculate PDP:  Other-deg layers
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: divide by zero encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/hdd/ML-fracture/src/utils.py:349: UserWarning: Attempting to set identical left == right == -0.2828427255153656 results in singular transformations; automatically expanding.
#   ax2.set_xlim([np.min(x_values_list[idx]), np.max(x_values_list[idx])])
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: divide by zero encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/hdd/ML-fracture/src/utils.py:349: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax2.set_xlim([np.min(x_values_list[idx]), np.max(x_values_list[idx])])

# %%
trainer.plot_partial_err(0.5)
# Out:
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: divide by zero encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %% [markdown]
# ## Baseline models

# %%
trainer.get_leaderboard(test_data_only=False)
# Out:
# Pytorch-Tabular metrics
# AutoGluon metrics
# This work metrics
# TabNet metrics
#             Program                      Model  Train RMSE  Train MSE  \
# 0         AutoGluon        WeightedEnsemble_L2    0.148549   0.022067
# 1         AutoGluon    ExtraTreesMSE_BAG_L1/T0    0.307828   0.094758
# 2         AutoGluon         CatBoost_BAG_L1/T0    0.455624   0.207593
# 3   Pytorch-Tabular     CategoryEmbeddingModel    0.755365   0.570576
# 4         AutoGluon  RandomForestMSE_BAG_L1/T0    0.322915   0.104274
# 5   Pytorch-Tabular        TabTransformerModel    0.622672   0.387721
# 6         AutoGluon       LightGBMXT_BAG_L1/T0    0.756768   0.572698
# 7         AutoGluon   NeuralNetMXNet_BAG_L1/T0    0.600400   0.360480
# 8         AutoGluon       LightGBMLarge_BAG_L1    0.392120   0.153758
# 9         AutoGluon   KNeighborsDist_BAG_L1/T0    0.000000   0.000000
# 10        AutoGluon  NeuralNetFastAI_BAG_L1/T0    0.744405   0.554139
# 11        This work                         --    0.714434   0.510416
# 12  Pytorch-Tabular               AutoIntModel    0.711715   0.506538
# 13  Pytorch-Tabular                TabNetModel    0.905065   0.819142
# 14        AutoGluon         LightGBM_BAG_L1/T0    0.721392   0.520407
# 15        AutoGluon   KNeighborsUnif_BAG_L1/T0    0.749981   0.562471
# 16        AutoGluon          XGBoost_BAG_L1/T0    0.336216   0.113041
# 17           TabNet                     TabNet    2.760457   7.620120
#
#     Train MAE  Train MAPE  Train R2  Test RMSE  Test MSE  Test MAE  Test MAPE  \
# 0    0.108680    0.029400  0.985390   0.724224  0.524500  0.571336   0.132024
# 1    0.225845    0.060840  0.937261   0.741801  0.550269  0.596621   0.137536
# 2    0.352211    0.095689  0.862554   0.751698  0.565050  0.603666   0.143649
# 3    0.594906    0.157543  0.622225   0.754042  0.568580  0.595165   0.139592
# 4    0.240864    0.065146  0.930961   0.777291  0.604181  0.623585   0.143393
# 5    0.451749    0.119419  0.743292   0.780103  0.608561  0.625066   0.152874
# 6    0.580746    0.158594  0.620820   0.783549  0.613948  0.632253   0.150432
# 7    0.404017    0.116534  0.761328   0.783982  0.614627  0.621150   0.154157
# 8    0.285974    0.079345  0.898198   0.796752  0.634814  0.640135   0.148936
# 9    0.000000    0.000000  1.000000   0.796943  0.635118  0.621102   0.142251
# 10   0.563975    0.151987  0.633108   0.797421  0.635879  0.640363   0.150136
# 11   0.537103    0.144853  0.662057   0.803248  0.645208  0.648966   0.148603
# 12   0.540341    0.144669  0.664624   0.805550  0.648911  0.681527   0.161002
# 13   0.707101    0.197254  0.457651   0.809572  0.655407  0.653497   0.158643
# 14   0.553558    0.151184  0.655442   0.813521  0.661816  0.667697   0.155992
# 15   0.528655    0.144221  0.627591   0.834293  0.696045  0.669606   0.156051
# 16   0.256361    0.064100  0.925156   0.837919  0.702108  0.692199   0.155991
# 17   2.265506    0.479946 -4.045234   2.728620  7.445367  2.385242   0.488021
#
#      Test R2  Validation RMSE  Validation MSE  Validation MAE  \
# 0   0.621031         0.593655        0.352426        0.488004
# 1   0.602412         0.654738        0.428682        0.532900
# 2   0.591732         0.723368        0.523261        0.583249
# 3   0.589182         0.772039        0.596044        0.620847
# 4   0.563459         0.698249        0.487552        0.568490
# 5   0.560294         0.776063        0.602273        0.632551
# 6   0.556401         0.786766        0.619001        0.639567
# 7   0.555911         0.754857        0.569809        0.583816
# 8   0.541325         0.718182        0.515785        0.585988
# 9   0.541105         0.644425        0.415284        0.506637
# 10  0.540555         0.825708        0.681794        0.636028
# 11  0.533815         0.773695        0.598604        0.609007
# 12  0.531140         0.761869        0.580445        0.598621
# 13  0.526446         0.802204        0.643532        0.633267
# 14  0.521815         0.788471        0.621687        0.633900
# 15  0.497084         0.807733        0.652432        0.620949
# 16  0.492703         0.708017        0.501288        0.571012
# 17 -4.379531         2.820535        7.955416        2.352279
#
#     Validation MAPE  Validation R2
# 0          0.121689       0.756235
# 1          0.132919       0.703491
# 2          0.146717       0.638073
# 3          0.153205       0.587730
# 4          0.141189       0.662772
# 5          0.156252       0.583422
# 6          0.159896       0.571852
# 7          0.153659       0.605876
# 8          0.145138       0.643244
# 9          0.125666       0.712758
# 10         0.161470       0.528420
# 11         0.152266       0.585960
# 12         0.150152       0.598520
# 13         0.161615       0.554885
# 14         0.158744       0.569994
# 15         0.150021       0.548728
# 16         0.135853       0.653271
# 17         0.490790      -4.502570

# %%
trainer.plot_truth_pred(program='pytorch_tabular', upper_lim=9)
# Out:
# Making baseline predictions...
# CategoryEmbeddingModel 1/4

# %%
trainer.plot_truth_pred(program='autogluon', upper_lim=9)
# Out:
# Making baseline predictions...
# ExtraTreesMSE_BAG_L1/T0 1/12
# NeuralNetMXNet_BAG_L1/T0 2/12
# LightGBMLarge_BAG_L1 3/12
# CatBoost_BAG_L1/T0 4/12
# WeightedEnsemble_L2 5/12
# RandomForestMSE_BAG_L1/T0 6/12
# KNeighborsDist_BAG_L1/T0 7/12
# LightGBM_BAG_L1/T0 8/12
# LightGBMXT_BAG_L1/T0 9/12
# KNeighborsUnif_BAG_L1/T0 10/12
# XGBoost_BAG_L1/T0 11/12
# NeuralNetFastAI_BAG_L1/T0 12/12
# Plotting...
# ExtraTreesMSE_BAG_L1/T0 1/12
# Train Loss: 0.0267, R2: 0.8761
# Validation Loss: 0.1371, R2: 0.0381
# Test Loss: 0.1175, R2: 0.5896
# NeuralNetMXNet_BAG_L1/T0 2/12
# Train Loss: 0.0422, R2: 0.8042
# Validation Loss: 0.1308, R2: 0.0825
# Test Loss: 0.1437, R2: 0.4980
# LightGBMLarge_BAG_L1 3/12
# Train Loss: 0.0466, R2: 0.7837
# Validation Loss: 0.0860, R2: 0.3967
# Test Loss: 0.2051, R2: 0.2836
# CatBoost_BAG_L1/T0 4/12
# Train Loss: 0.0537, R2: 0.7510
# Validation Loss: 0.1115, R2: 0.2175
# Test Loss: 0.2197, R2: 0.2326
# WeightedEnsemble_L2 5/12
# Train Loss: 0.0478, R2: 0.7782
# Validation Loss: 0.0788, R2: 0.4469
# Test Loss: 0.2216, R2: 0.2258
# RandomForestMSE_BAG_L1/T0 6/12
# Train Loss: 0.0256, R2: 0.8810
# Validation Loss: 0.0852, R2: 0.4021
# Test Loss: 0.2442, R2: 0.1468
# KNeighborsDist_BAG_L1/T0 7/12
# Train Loss: 0.0000, R2: 1.0000
# Validation Loss: 0.1224, R2: 0.1410
# Test Loss: 0.2766, R2: 0.0336
# LightGBM_BAG_L1/T0 8/12
# Train Loss: 0.2155, R2: 0.0000
# Validation Loss: 0.1897, R2: -0.3313
# Test Loss: 0.3098, R2: -0.0823
# LightGBMXT_BAG_L1/T0 9/12
# Train Loss: 0.2155, R2: 0.0000
# Validation Loss: 0.1897, R2: -0.3313
# Test Loss: 0.3098, R2: -0.0823
# KNeighborsUnif_BAG_L1/T0 10/12
# Train Loss: 0.1583, R2: 0.2656
# Validation Loss: 0.1232, R2: 0.1355
# Test Loss: 0.3099, R2: -0.0825
# XGBoost_BAG_L1/T0 11/12
# Train Loss: 0.0317, R2: 0.8529
# Validation Loss: 0.1077, R2: 0.2440
# Test Loss: 0.3189, R2: -0.1141
# NeuralNetFastAI_BAG_L1/T0 12/12
# Train Loss: 0.2196, R2: -0.0189
# Validation Loss: 0.1725, R2: -0.2103
# Test Loss: 0.3237, R2: -0.1309
