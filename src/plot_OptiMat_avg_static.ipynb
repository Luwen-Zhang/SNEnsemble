# %% [markdown]
# ### Import configuration and data.

# %%
# %load_ext autoreload
# %autoreload 2

from trainer import *

trainer = load_trainer(path='../output/OptiMat_avg_static/base_OptiMat_avg_static/trainer.pkl')

# %% [markdown]
# ### Gaussian process-based Bayes hyperparameter optimization (Optional)

# %% [markdown]
# ### Training

# %%
trainer.plot_loss()

# %% [markdown]
# ### Plotting predictions and comparing with baseline models.

# %%
trainer.plot_truth_pred(log_trans=False)
# Out:
# Train Loss: 0.0117, R2: 0.9013
# Validation Loss: 0.3743, R2: -3.9813
# Test Loss: 1862.6124, R2: -14902.6298

# %% [markdown]
# ### Permutation feature importance

# %%
trainer.plot_feature_importance()

# %% [markdown]
# ### Partial dependence

# %%
trainer.plot_partial_dependence(log_trans=True, lower_lim=1, upper_lim=3)
# Out:
# Calculate PDP:  Width
# Calculate PDP:  Area
# Calculate PDP:  Percentage of Fibre in 45-deg Direction
# Calculate PDP:  Percentage of Fibre in 0-deg Direction
# Calculate PDP:  Length(nominal)
# Calculate PDP:  Thickness
# Calculate PDP:  0-deg layers
# Calculate PDP:  45-deg layers
# Calculate PDP:  90-deg layers
# Calculate PDP:  Other-deg layers
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: divide by zero encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/hdd/ML-fracture/src/utils.py:349: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax2.set_xlim([np.min(x_values_list[idx]), np.max(x_values_list[idx])])
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: divide by zero encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/hdd/ML-fracture/src/utils.py:349: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax2.set_xlim([np.min(x_values_list[idx]), np.max(x_values_list[idx])])

# %%
trainer.plot_partial_err(100)
# Out:
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: divide by zero encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/xlluo/anaconda3/envs/ML-fracture/lib/python3.7/site-packages/numpy/lib/histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %% [markdown]
# ## Baseline models

# %%
trainer.get_leaderboard(test_data_only=False)
# Out:
# Pytorch-Tabular metrics
# AutoGluon metrics
# This work metrics
# TabNet metrics
#             Program                      Model  Train RMSE  Train MSE  \
# 0         AutoGluon   KNeighborsDist_BAG_L1/T0    0.000000   0.000000
# 1         AutoGluon   KNeighborsUnif_BAG_L1/T0    0.175669   0.030860
# 2         AutoGluon  RandomForestMSE_BAG_L1/T0    0.099387   0.009878
# 3         AutoGluon    ExtraTreesMSE_BAG_L1/T0    0.100771   0.010155
# 4         AutoGluon         CatBoost_BAG_L1/T0    0.191930   0.036837
# 5         AutoGluon       LightGBMLarge_BAG_L1    0.179901   0.032364
# 6         AutoGluon          XGBoost_BAG_L1/T0    0.090215   0.008139
# 7         AutoGluon   NeuralNetMXNet_BAG_L1/T0    0.156983   0.024644
# 8         AutoGluon         LightGBM_BAG_L1/T0    0.330781   0.109416
# 9   Pytorch-Tabular               AutoIntModel    0.358746   0.128699
# 10        AutoGluon        WeightedEnsemble_L2    0.150346   0.022604
# 11        AutoGluon  NeuralNetFastAI_BAG_L1/T0    0.227471   0.051743
# 12        AutoGluon       LightGBMXT_BAG_L1/T0    2.106133   4.435796
# 13  Pytorch-Tabular                TabNetModel    0.285160   0.081316
# 14        This work                         --    0.108155   0.011697
# 15  Pytorch-Tabular     CategoryEmbeddingModel    0.153982   0.023710
# 16  Pytorch-Tabular        TabTransformerModel    0.527047   0.277779
# 17           TabNet                     TabNet    7.148424  51.099968
#
#     Train MAE  Train MAPE    Train R2   Test RMSE      Test MSE   Test MAE  \
# 0    0.000000    0.000000    1.000000    0.138586      0.019206   0.093807
# 1    0.105941    0.045829    0.739561    0.169291      0.028660   0.106336
# 2    0.053363    0.025074    0.916638    0.242835      0.058969   0.137549
# 3    0.053617    0.025118    0.914299    0.245740      0.060388   0.127057
# 4    0.138376    0.061771    0.689116    0.246176      0.060603   0.184402
# 5    0.122983    0.054603    0.726863    0.303195      0.091927   0.213920
# 6    0.065353    0.025760    0.931313    0.303603      0.092175   0.188336
# 7    0.106325    0.041399    0.792020    0.310784      0.096587   0.191893
# 8    0.227022    0.101775    0.076592    0.345164      0.119138   0.273642
# 9    0.237179    0.106555   -0.086147    0.471359      0.222179   0.283075
# 10   0.110639    0.048192    0.809236    0.684564      0.468628   0.312762
# 11   0.160418    0.071810    0.563317    1.076351      1.158532   0.478351
# 12   2.080508    0.796526  -36.435641    2.097564      4.399772   2.068533
# 13   0.212290    0.088962    0.313737   15.040812    226.226028   5.174043
# 14   0.058184    0.024206    0.901280   43.157997   1862.612671  14.258608
# 15   0.115277    0.048589    0.799897   50.231228   2523.176270  16.476116
# 16   0.415603    0.166284   -1.344299   67.894348   4609.642090  22.424376
# 17   3.069485    1.458210 -430.255198  133.304779  17770.164062  44.918579
#
#     Test MAPE        Test R2  Validation RMSE  Validation MSE  Validation MAE  \
# 0    0.042011       0.846324         0.263325        0.069340        0.143034
# 1    0.048188       0.770681         0.277525        0.077020        0.160591
# 2    0.056047       0.528161         0.230465        0.053114        0.099114
# 3    0.051187       0.516806         0.230901        0.053315        0.096438
# 4    0.080918       0.515091         0.250869        0.062935        0.166402
# 5    0.094355       0.264448         0.285661        0.081602        0.176158
# 6    0.074892       0.262466         0.225175        0.050704        0.140409
# 7    0.073142       0.227166         0.234578        0.055027        0.153150
# 8    0.117711       0.046718         0.273028        0.074544        0.209005
# 9    0.119051      -0.777760         0.401010        0.160809        0.258022
# 10   0.121161      -2.749711         0.213536        0.045597        0.137416
# 11   0.187518      -8.269951         0.222952        0.049708        0.152328
# 12   0.796203     -34.204624         2.120650        4.497156        2.102932
# 13   1.979586   -1809.139676         0.271107        0.073499        0.215053
# 14   5.428432  -14902.629766         0.611781        0.374275        0.293308
# 15   6.258010  -20188.106997         0.464805        0.216044        0.264767
# 16   8.518078  -36882.891158         0.576116        0.331910        0.472499
# 17  17.152849 -142186.368069         1.591959        2.534332        1.016646
#
#     Validation MAPE  Validation R2
# 0          0.061832       0.077140
# 1          0.068590      -0.025077
# 2          0.044101       0.293093
# 3          0.042878       0.290418
# 4          0.069956       0.162383
# 5          0.075385      -0.086058
# 6          0.058297       0.325175
# 7          0.062260       0.267636
# 8          0.083165       0.007878
# 9          0.102532      -1.140228
# 10         0.056500       0.393137
# 11         0.062616       0.338432
# 12         0.788843     -58.853382
# 13         0.083670       0.021789
# 14         0.128810      -3.981293
# 15         0.111204      -1.875364
# 16         0.182225      -3.417438
# 17         0.395666     -32.729832

# %%
trainer.plot_truth_pred(program='pytorch_tabular', log_trans=False)
# Out:
# Making baseline predictions...
# AutoIntModel 1/4
# TabNetModel 2/4
# CategoryEmbeddingModel 3/4
# TabTransformerModel 4/4
# Plotting...
# AutoIntModel 1/4
# Train Loss: 0.1287, R2: -0.0861
# Validation Loss: 0.1608, R2: -1.1402
# Test Loss: 0.2222, R2: -0.7778
# TabNetModel 2/4
# Train Loss: 0.0813, R2: 0.3137
# Validation Loss: 0.0735, R2: 0.0218
# Test Loss: 226.2260, R2: -1809.1397
# CategoryEmbeddingModel 3/4
# Train Loss: 0.0237, R2: 0.7999
# Validation Loss: 0.2160, R2: -1.8754
# Test Loss: 2523.1763, R2: -20188.1070
# TabTransformerModel 4/4
# Train Loss: 0.2778, R2: -1.3443
# Validation Loss: 0.3319, R2: -3.4174
# Test Loss: 4609.6426, R2: -36882.8912

# %%
trainer.plot_truth_pred(program='autogluon', log_trans=False)
# Out:
# Making baseline predictions...
# KNeighborsDist_BAG_L1/T0 1/12
# KNeighborsUnif_BAG_L1/T0 2/12
# RandomForestMSE_BAG_L1/T0 3/12
# ExtraTreesMSE_BAG_L1/T0 4/12
# CatBoost_BAG_L1/T0 5/12
# LightGBMLarge_BAG_L1 6/12
# XGBoost_BAG_L1/T0 7/12
# NeuralNetMXNet_BAG_L1/T0 8/12
# LightGBM_BAG_L1/T0 9/12
# WeightedEnsemble_L2 10/12
# NeuralNetFastAI_BAG_L1/T0 11/12
# LightGBMXT_BAG_L1/T0 12/12
# Plotting...
# KNeighborsDist_BAG_L1/T0 1/12
# Train Loss: 0.0000, R2: 1.0000
# Validation Loss: 0.0693, R2: 0.0771
# Test Loss: 0.0192, R2: 0.8463
# KNeighborsUnif_BAG_L1/T0 2/12
# Train Loss: 0.0309, R2: 0.7396
# Validation Loss: 0.0770, R2: -0.0251
# Test Loss: 0.0287, R2: 0.7707
# RandomForestMSE_BAG_L1/T0 3/12
# Train Loss: 0.0099, R2: 0.9166
# Validation Loss: 0.0531, R2: 0.2931
# Test Loss: 0.0590, R2: 0.5282
# ExtraTreesMSE_BAG_L1/T0 4/12
# Train Loss: 0.0102, R2: 0.9143
# Validation Loss: 0.0533, R2: 0.2904
# Test Loss: 0.0604, R2: 0.5168
# CatBoost_BAG_L1/T0 5/12
# Train Loss: 0.0368, R2: 0.6891
# Validation Loss: 0.0629, R2: 0.1624
# Test Loss: 0.0606, R2: 0.5151
# LightGBMLarge_BAG_L1 6/12
# Train Loss: 0.0324, R2: 0.7269
# Validation Loss: 0.0816, R2: -0.0861
# Test Loss: 0.0919, R2: 0.2644
# XGBoost_BAG_L1/T0 7/12
# Train Loss: 0.0081, R2: 0.9313
# Validation Loss: 0.0507, R2: 0.3252
# Test Loss: 0.0922, R2: 0.2625
# NeuralNetMXNet_BAG_L1/T0 8/12
# Train Loss: 0.0246, R2: 0.7920
# Validation Loss: 0.0550, R2: 0.2676
# Test Loss: 0.0966, R2: 0.2272
# LightGBM_BAG_L1/T0 9/12
# Train Loss: 0.1094, R2: 0.0766
# Validation Loss: 0.0745, R2: 0.0079
# Test Loss: 0.1191, R2: 0.0467
# WeightedEnsemble_L2 10/12
# Train Loss: 0.0226, R2: 0.8092
# Validation Loss: 0.0456, R2: 0.3931
# Test Loss: 0.4686, R2: -2.7497
# NeuralNetFastAI_BAG_L1/T0 11/12
# Train Loss: 0.0517, R2: 0.5633
# Validation Loss: 0.0497, R2: 0.3384
# Test Loss: 1.1585, R2: -8.2700
# LightGBMXT_BAG_L1/T0 12/12
# Train Loss: 4.4358, R2: -36.4356
# Validation Loss: 4.4972, R2: -58.8534
# Test Loss: 4.3998, R2: -34.2046
